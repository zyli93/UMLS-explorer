# %%
import pickle
import pandas as pd

# %%
# semantic types sty are parsed from networkx nodes
with open('semanticTypes.pickle', 'rb') as handle:
    sty = pickle.load(handle)

# %%
# MRCONSO.RRF is used to link CUI's to their concept names STR
mrconso = pd.read_csv('/Users/qinyilong/Desktop/ScAi/MRCONSO.RRF', sep='|', header=None, dtype=object)
mrconso = mrconso.drop(18, axis=1) # last column is meaningless because the entry ends with '|'
mrconso.columns = ["CUI", "LAT", "TS", "LUI", "STT", "SUI", "ISPREF", "AUI", "SAUI", "SCUI", "SDUI", "SAB", "TTY", "CODE", "STR", "SRL", "SUPPRESS", "CVF"]

# %%
# definitions of semantic types srdef are used to link STY's to their TUI's
srdef = pd.read_csv('/Users/qinyilong/Desktop/ScAi/SRDEF', sep='|', header=None, dtype=object)
srdef = srdef.drop(10, axis=1) # last column is meaningless because the entry ends with '|'
srdef.columns = ["RT", "UI", "STYorRL", "STNorRTN", "DEF", "EX", "UN", "NH", "ABR", "RIH"]

# %%
# MRSTY.RRF is used to provide categorization of concepts' CUI's to semantic types' TUI's
mrsty = pd.read_csv('/Users/qinyilong/Desktop/ScAi/MRSTY.RRF', sep='|', header=None, dtype=object)
mrsty = mrsty.drop(6, axis=1) # last column is meaningless because the entry ends with '|'
mrsty.columns = ["CUI", "TUI", "STN", "STY", "ATUI", "CVF"]

# %%
mrconso
# Out:
#                CUI  LAT TS        LUI STT        SUI ISPREF        AUI SAUI  \
# 0         C0000005  ENG  P   L0000005  PF   S0007492      Y  A26634265  NaN
# 1         C0000005  ENG  S   L0270109  PF   S0007491      Y  A26634266  NaN
# 2         C0000005  FRE  P   L6220710  PF   S7133957      Y  A13433185  NaN
# 3         C0000005  FRE  S   L6215648  PF   S7133916      Y  A27488794  NaN
# 4         C0000005  FRE  S   L6215656  PF   S7133956      Y  A27614225  NaN
# ...            ...  ... ..        ...  ..        ...    ...        ...  ...
# 14433445  C4721340  ENG  P  L14979070  PF  S18222043      Y  A29738197  NaN
# 14433446  C4721341  ENG  P  L14980186  PF  S18222525      Y  A29739672  NaN
# 14433447  C4721341  ENG  S  L14980185  PF  S18222524      Y  A29739673  NaN
# 14433448  C4721342  ENG  P  L14980190  PF  S18222545      Y  A29739709  NaN
# 14433449  C4721342  ENG  S  L14980191  PF  S18222544      Y  A29739708  NaN
#
#                SCUI     SDUI          SAB  TTY                 CODE  \
# 0          M0019694  D012711          MSH  PEP              D012711
# 1          M0019694  D012711          MSH   ET              D012711
# 2          M0019694  D012711       MSHFRE  PEP              D012711
# 3          M0019694  D012711       MSHFRE   ET              D012711
# 4          M0019694  D012711       MSHFRE   ET              D012711
# ...             ...      ...          ...  ...                  ...
# 14433445  447562003      NaN  SNOMEDCT_US   XM            447562003
# 14433446        NaN      NaN          SRC  VPT      V-MVX2018_08_31
# 14433447        NaN      NaN          SRC  VAB      V-MVX2018_08_31
# 14433448        NaN      NaN          SRC  VPT  V-MED-RT_2018_09_04
# 14433449        NaN      NaN          SRC  VAB  V-MED-RT_2018_09_04
#
#                                                         STR SRL SUPPRESS  CVF
# 0                            (131)I-Macroaggregated Albumin   0        N  256
# 1                                                (131)I-MAA   0        N  256
# 2             Macroagrégats d'albumine marquée à l'iode 131   3        N  NaN
# 3                                                 MAA-I 131   3        N  NaN
# 4         Macroagrégats d'albumine humaine marquée à l'i...   3        N  NaN
# ...                                                     ...  ..      ...  ...
# 14433445      SNOMEDCT_US_2018_09_01 to ICD10_2016 Mappings   9        N  NaN
# 14433446              Manufacturers of Vaccines, 2018_08_31   0        N  NaN
# 14433447                                      MVX2018_08_31   0        N  NaN
# 14433448       Medication Reference Terminology, 2018_09_04   0        N  NaN
# 14433449                                  MED-RT_2018_09_04   0        N  NaN
#
# [14433450 rows x 18 columns]

# %%
mrsty
# Out:
#               CUI   TUI  STN  STY ATUI  CVF
# 0        C0000005  T116  NaN  NaN  NaN  NaN
# 1        C0000005  T121  NaN  NaN  NaN  NaN
# 2        C0000005  T130  NaN  NaN  NaN  NaN
# 3        C0000039  T109  NaN  NaN  NaN  NaN
# 4        C0000039  T121  NaN  NaN  NaN  NaN
# ...           ...   ...  ...  ...  ...  ...
# 4120569  C4721338  T058  NaN  NaN  NaN  NaN
# 4120570  C4721339  T170  NaN  NaN  NaN  NaN
# 4120571  C4721340  T170  NaN  NaN  NaN  NaN
# 4120572  C4721341  T170  NaN  NaN  NaN  NaN
# 4120573  C4721342  T170  NaN  NaN  NaN  NaN
#
# [4120574 rows x 6 columns]

# %%
srdef
# Out:
#       RT    UI               STYorRL  STNorRTN  \
# 0    STY  T001              Organism      A1.1
# 1    STY  T002                 Plant  A1.1.3.3
# 2    STY  T004                Fungus  A1.1.3.2
# 3    STY  T005                 Virus    A1.1.4
# 4    STY  T007             Bacterium    A1.1.2
# ..   ...   ...                   ...       ...
# 176   RL  T189  spatially_related_to        R2
# 177   RL  T193              analyzes      R5.3
# 178   RL  T198             branch_of      R1.6
# 179   RL  T199          tributary_of      R1.7
# 180   RL  T202         ingredient_of      R1.8
#
#                                                    DEF   EX   UN   NH   ABR  \
# 0    Generally, a living individual, including all ...  NaN  NaN  NaN  orgm
# 1    An organism having cellulose cell walls, growi...  NaN  NaN  NaN  plnt
# 2    A eukaryotic organism characterized by the abs...  NaN  NaN  NaN  fngs
# 3    An organism consisting of a core of a single n...  NaN  NaN  NaN  virs
# 4    A small, typically one-celled, prokaryotic mic...  NaN  NaN  NaN  bact
# ..                                                 ...  ...  ...  ...   ...
# 176                        Related by place or region.  NaN  NaN  NaN    SP
# 177  Studies or examines using established quantita...  NaN  NaN  NaN    AN
# 178  Arises from the division of. For example, the ...  NaN  NaN  NaN    BR
# 179  Merges with. For example, the confluence of ve...  NaN  NaN  NaN    TB
# 180  Is a component of, as in a constituent of a pr...  NaN  NaN  NaN    IG
#
#                       RIH
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ..                    ...
# 176  spatially_related_to
# 177           analyzed_by
# 178            has_branch
# 179         has_tributary
# 180        has_ingredient
#
# [181 rows x 10 columns]

# %%
sty_to_tui = dict((el, srdef[srdef.STYorRL == el][["UI"]].values[0][0]) for el in sty)

# %%
sty_to_cuis = dict((el, []) for el in sty)
for el in sty_to_cuis:
    tui = sty_to_tui[el]
    sty_to_cuis[el] = mrsty[mrsty.TUI == tui].CUI.tolist()

# %%
for el in sty_to_cuis:
    print(el)
    print(sty_to_cuis[el])
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
with open('STY_to_CUIs.pickle', 'wb') as handle:
    pickle.dump(sty_to_cuis, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
sty_to_concepts = sty_to_cuis

# %%
for el in sty_to_concepts:
    for cui in sty_to_concepts[el]:
        print(mrconso[mrconso.CUI == cui].STR)
